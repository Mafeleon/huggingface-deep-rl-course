# %% [markdown]
# # Bonus Unit 1: Let's train Huggy the Dog 🐶 to fetch a stick

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit2/thumbnail.png" alt="Bonus Unit 1Thumbnail">
#
# In this notebook, we'll reinforce what we learned in the first Unit by **teaching Huggy the Dog to fetch the stick and then play with it directly in your browser**
#
# ⬇️ Here is an example of what **you will achieve at the end of the unit.** ⬇️ (launch ▶ to see)

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.mp4" type="video/mp4"></video>

# %% [markdown]
# ### The environment 🎮
#
# - Huggy the Dog, an environment created by [Thomas Simonini](https://twitter.com/ThomasSimonini) based on [Puppo The Corgi](https://blog.unity.com/technology/puppo-the-corgi-cuteness-overload-with-the-unity-ml-agents-toolkit)
#
# ### The library used 📚
#
# - [MLAgents](https://github.com/Unity-Technologies/ml-agents)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Understand **the state space, action space and reward function used to train Huggy**.
# - **Train your own Huggy** to fetch the stick.
# - Be able to play **with your trained Huggy directly in your browser**.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
#
# Before diving into the notebook, you need to:
#
# 🔲 📚 **Develop an understanding of the foundations of Reinforcement learning** (MC, TD, Rewards hypothesis...) by doing Unit 1
#
# 🔲 📚 **Read the introduction to Huggy** by doing Bonus Unit 1

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Clone the repository 🔽
#
# - We need to clone the repository, that contains **ML-Agents.**

# %%
# %%capture
# Clone the repository (can take 3min)
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %% [markdown]
# ## Setup the Virtual Environment 🔽
# - In order for the **ML-Agents** to run successfully in Colab,  Colab's Python version must meet the library's Python requirements.
#
# - We can check for the supported Python version under the `python_requires` parameter in the `setup.py` files. These files are required to set up the **ML-Agents** library for use and can be found in the following locations:
#   - `/content/ml-agents/ml-agents/setup.py`
#   - `/content/ml-agents/ml-agents-envs/setup.py`
#
# - Colab's Current Python version(can be checked using `!python --version`) doesn't match the library's `python_requires` parameter, as a result installation may silently fail and lead to errors like these, when executing the same commands later:
#   - `/bin/bash: line 1: mlagents-learn: command not found`
#   - `/bin/bash: line 1: mlagents-push-to-hf: command not found`
#
# - To resolve this, we'll create a virtual environment with a Python version compatible with the **ML-Agents** library.
#
# `Note:` *For future compatibility, always check the `python_requires` parameter in the installation files and set your virtual environment to the maximum supported Python version in the given below script if the Colab's Python version is not compatible*

# %%
# Colab's Current Python Version (Incompatible with ML-Agents)
# !python --version
# Out:
# Python 3.12.13

# %%
# !/usr/local/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !/usr/local/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %%
# Download and install Miniconda (if not already present and configured)
# -b for batch mode (no prompts)
# -f for force (overwrite if directory exists)
# -p /usr/local for installation prefix
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
# !chmod +x miniconda.sh
# !./miniconda.sh -b -f -p /usr/local

# Create a new conda environment named mlagents_env with Python 3.10.12
# This provides better isolation than modifying the base environment
# !/usr/local/bin/conda create -n mlagents_env python=3.10.12 ujson -y

# IMPORTANT: Modify the PATH environment variable to prioritize the new conda environment
# This ensures `python`, `pip`, `mlagents-learn` etc. refer to the correct environment
import os
os.environ['PATH'] = '/usr/local/envs/mlagents_env/bin:' + os.environ['PATH']
os.environ['CONDA_DEFAULT_ENV'] = 'mlagents_env'
os.environ['CONDA_PREFIX'] = '/usr/local/envs/mlagents_env'

print(f"PATH updated: {os.environ['PATH']}")
print("Conda environment 'mlagents_env' created and its bin directory added to PATH.")
# Out:
# --2026-05-23 06:08:18--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163179296 (156M) [application/octet-stream]
# Saving to: ‘miniconda.sh’
#
# miniconda.sh        100%[===================>] 155.62M   238MB/s    in 0.7s
#
# 2026-05-23 06:08:18 (238 MB/s) - ‘miniconda.sh’ saved [163179296/163179296]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.3.2
#     latest version: 26.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/mlagents_env
#
#   added / updated specs:
#     - python=3.10.12
#     - ujson
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |           52_gnu           7 KB
#     ca-certificates-2026.5.14  |       h06a4308_0         107 KB
#     libgcc-15.2.0              |       h69a1729_8         803 KB
#     libgcc-ng-15.2.0           |       h166f726_8          28 KB
#     libstdcxx-15.2.0           |       h39759b7_8         3.7 MB
#     libstdcxx-ng-15.2.0        |       hc03a8fd_8          28 KB
#     packaging-26.0             |  py310h06a4308_0         165 KB
#     python-3.10.12             |       h955ad1f_0        26.8 MB
#     setuptools-82.0.1          |  py310h06a4308_0         1.2 MB
#     ujson-5.11.0               |  py310hbdd6827_0         141 KB
#     wheel-0.46.3               |  py310h06a4308_0          54 KB
#     ------------------------------------------------------------
#                                            Total:        33.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-52_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2026.5.14-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
#   libffi             pkgs/main/linux-64::libffi-3.4.8-hc5d346e_2
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_8
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_8
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_8
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_8
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-h47b2149_1
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.6-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-26.0-py310h06a4308_0
#   pip                pkgs/main/noarch::pip-26.0.1-pyhc872135_1
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.10.12-h955ad1f_0
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-82.0.1-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.51.2-h3e8d24a_0
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026a-he532380_0
#   ujson              pkgs/main/linux-64::ujson-5.11.0-py310hbdd6827_0
#   wheel              pkgs/main/linux-64::wheel-0.46.3-py310h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.1-h47b2149_1
#
#
#
# Downloading and Extracting Packages:
# python-3.10.12       | 26.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libstdcxx-15.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# setuptools-82.0.1    | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libgcc-15.2.0        | 803 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# packaging-26.0       | 165 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# ujson-5.11.0         | 141 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# wheel-0.46.3         | 54 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 28 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      | :   0% 0/1 [00:00<?, ?it/s]
# python-3.10.12       | 26.8 MB   | :   1% 0.006409949534593647/1 [00:00<00:16, 16.40s/it]
#
# setuptools-82.0.1    | 1.2 MB    | :   1% 0.012863725691099424/1 [00:00<00:07,  8.07s/it]
#
#
# libgcc-15.2.0        | 803 KB    | :  18% 0.17933799062056083/1 [00:00<00:00,  1.74it/s]
#
#
#
# packaging-26.0       | 165 KB    | :  48% 0.484200820398851/1 [00:00<00:00,  4.57it/s]
#
#
#
# packaging-26.0       | 165 KB    | : 100% 1.0/1 [00:00<00:00,  4.57it/s]
#
#
# libgcc-15.2.0        | 803 KB    | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
#
#
#
#
# ujson-5.11.0         | 141 KB    | :  11% 0.11369645323136923/1 [00:00<00:01,  1.46s/it]
#
#
#
#
# ujson-5.11.0         | 141 KB    | : 100% 1.0/1 [00:00<00:00,  1.46s/it]
#
# setuptools-82.0.1    | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  8.07s/it]
# python-3.10.12       | 26.8 MB   | :  13% 0.12645082263698376/1 [00:00<00:01,  1.40s/it]
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | :  15% 0.14896983142696077/1 [00:00<00:01,  1.33s/it]
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | : 100% 1.0/1 [00:00<00:00,  1.33s/it]
#
#
#
#
#
#
# wheel-0.46.3         | 54 KB     | :  30% 0.29681697132194423/1 [00:00<00:00,  1.34it/s]
#
#
#
#
#
#
# wheel-0.46.3         | 54 KB     | : 100% 1.0/1 [00:00<00:00,  1.34it/s]
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 28 KB     | :  57% 0.5747965197866967/1 [00:00<00:00,  2.47it/s]
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 28 KB     | : 100% 1.0/1 [00:00<00:00,  2.47it/s]
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | :  58% 0.5758470406298327/1 [00:00<00:00,  2.30it/s]
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      | : 100% 1.0/1 [00:00<00:00,  3.71it/s]
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      | : 100% 1.0/1 [00:00<00:00,  3.71it/s]
# python-3.10.12       | 26.8 MB   | :  34% 0.3432236614432416/1 [00:00<00:00,  1.37it/s]
#
#
#
# packaging-26.0       | 165 KB    | : 100% 1.0/1 [00:00<00:00,  3.01it/s]
#
#
#
# packaging-26.0       | 165 KB    | : 100% 1.0/1 [00:00<00:00,  3.01it/s]
#
#
# libgcc-15.2.0        | 803 KB    | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
#
#
# libgcc-15.2.0        | 803 KB    | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
#
#
#
#
# ujson-5.11.0         | 141 KB    | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
#
#
#
#
# ujson-5.11.0         | 141 KB    | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
#
#
#
#
#
# python-3.10.12       | 26.8 MB   | :  64% 0.6374986173495863/1 [00:00<00:00,  1.98it/s]
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
#
#
#
#
#
#
# wheel-0.46.3         | 54 KB     | : 100% 1.0/1 [00:00<00:00,  2.32it/s]
#
#
#
#
#
#
# python-3.10.12       | 26.8 MB   | :  90% 0.8968102121581475/1 [00:00<00:00,  2.20it/s]
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 28 KB     | : 100% 1.0/1 [00:00<00:00,  1.85it/s]
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 28 KB     | : 100% 1.0/1 [00:00<00:00,  1.85it/s]
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | : 100% 1.0/1 [00:00<00:00,  1.70it/s]
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | : 100% 1.0/1 [00:00<00:00,  1.70it/s]
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      | : 100% 1.0/1 [00:00<00:00,  3.71it/s]
# python-3.10.12       | 26.8 MB   | : 100% 1.0/1 [00:00<00:00,  2.20it/s]
#
# setuptools-82.0.1    | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.07it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate mlagents_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# PATH updated: /usr/local/envs/mlagents_env/bin:/opt/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# Conda environment 'mlagents_env' created and its bin directory added to PATH.

# %% [markdown]
# ### Resolving the Conda Terms of Service Error
#
# The previous cell (`V_snxvzKZR58`) failed to set up the Python 3.10.12 environment due to a `CondaToSNonInteractiveError`. This meant you needed to explicitly accept the Conda Terms of Service. You've now successfully accepted them!
#
# To ensure a robust setup, I've modified the following cells to:
# 1. Create a dedicated **Conda environment named `mlagents_env` with Python 3.10.12**.
# 2. **Permanently update the `PATH`** within this Colab session to prioritize this new environment, ensuring commands like `python`, `pip`, and `mlagents-learn` correctly use it.
# 3. Explicitly call executables from `mlagents_env` where necessary.
#
# Please proceed by running the corrected setup cells below.

# %%
# Python Version in New Virtual Environment (Compatible with ML-Agents)
# This should now reflect Python 3.10.12 from the mlagents_env
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## Installing the dependencies 🔽

# %%
# Ensure we are in the ml-agents directory
# %cd /content/ml-agents

# Ensure core dependencies are installed first
# !/usr/local/envs/mlagents_env/bin/pip install attrs

# Verify attrs installation
# !/usr/local/envs/mlagents_env/bin/pip show attrs

# Use the pip from the new conda environment to ensure installation into mlagents_env
# Using absolute paths for editable installs for robustness
# !/usr/local/envs/mlagents_env/bin/pip install -e /content/ml-agents/ml-agents-envs
# !/usr/local/envs/mlagents_env/bin/pip install -e /content/ml-agents/ml-agents
# Out:
# /content/ml-agents
# Collecting attrs
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
# Installing collected packages: attrs
# Successfully installed attrs-26.1.0
# Name: attrs
# Version: 26.1.0
# Summary: Classes Without Boilerplate
# Home-page:
# Author:
# Author-email: Hynek Schlawack <hs@ox.cx>
# License-Expression: MIT
# Location: /usr/local/envs/mlagents_env/lib/python3.10/site-packages
# Requires:
# Required-by:
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting cloudpickle (from mlagents_envs==1.2.0.dev0)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting grpcio<=1.53.2,>=1.11.0 (from mlagents_envs==1.2.0.dev0)
#   Downloading grpcio-1.53.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting Pillow>=4.2.1 (from mlagents_envs==1.2.0.dev0)
#   Downloading pillow-12.2.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting protobuf<3.21,>=3.6 (from mlagents_envs==1.2.0.dev0)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Collecting pyyaml>=3.1.0 (from mlagents_envs==1.2.0.dev0)
#   Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting gym>=0.21.0 (from mlagents_envs==1.2.0.dev0)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 16.1 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pettingzoo==1.15.0 (from mlagents_envs==1.2.0.dev0)
#   Downloading PettingZoo-1.15.0.tar.gz (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 36.2 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy<1.24.0,>=1.23.5 (from mlagents_envs==1.2.0.dev0)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting filelock>=3.4.0 (from mlagents_envs==1.2.0.dev0)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting gym_notices>=0.0.4 (from gym>=0.21.0->mlagents_envs==1.2.0.dev0)
#   Downloading gym_notices-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading grpcio-1.53.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 70.5 MB/s  0:00:00
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 114.9 MB/s  0:00:00
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.0 MB/s  0:00:00
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading gym_notices-0.1.0-py3-none-any.whl (3.3 kB)
# Downloading pillow-12.2.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 31.8 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 46.4 MB/s  0:00:00
# Building wheels for collected packages: mlagents_envs, pettingzoo, gym
#   Building editable for mlagents_envs (pyproject.toml) ... done
#   Created wheel for mlagents_envs: filename=mlagents_envs-1.2.0.dev0-0.editable-py3-none-any.whl size=3925 sha256=c44fb9d61e4a6f14b62aa1ef6051ca25e36a7b0e548d27c6d8b772b6ecc224ba
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lza4fg80/wheels/06/a4/44/559ecb18c6173396ce39acd3f9593bfb562b00fa707a216311
#   Building wheel for pettingzoo (pyproject.toml) ... done
#   Created wheel for pettingzoo: filename=pettingzoo-1.15.0-py3-none-any.whl size=875758 sha256=08bf6e92a4dc9b56b2bb6913365e8c54408bb0cc42851826f59707e0445808c5
#   Stored in directory: /root/.cache/pip/wheels/e3/35/ac/76984cb1c12902d190c818d57c43d25c3f9281591a640ccd13
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827727 sha256=19e56db4afc1fd9712d66d303a95ba0262c63095a6389aba09b446365dedc538
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built mlagents_envs pettingzoo gym
# Installing collected packages: gym_notices, pyyaml, protobuf, Pillow, numpy, grpcio, filelock, cloudpickle, gym, pettingzoo, mlagents_envs
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [mlagents_envs]
# Successfully installed Pillow-12.2.0 cloudpickle-3.1.2 filelock-3.29.0 grpcio-1.53.2 gym-0.26.2 gym_notices-0.1.0 mlagents_envs-1.2.0.dev0 numpy-1.23.5 pettingzoo-1.15.0 protobuf-3.20.3 pyyaml-6.0.3
# Obtaining file:///content/ml-agents/ml-agents
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: grpcio<=1.53.2,>=1.11.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (1.53.2)
# Collecting h5py>=2.9.0 (from mlagents==1.2.0.dev0)
#   Downloading h5py-3.16.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: mlagents_envs==1.2.0.dev0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (1.2.0.dev0)
# Requirement already satisfied: numpy<1.24.0,>=1.23.5 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (26.0)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (12.2.0)
# Requirement already satisfied: protobuf<3.21,>=3.6 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (3.20.3)
# Requirement already satisfied: pyyaml>=3.1.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (6.0.3)
# Collecting torch<=2.8.0,>=2.1.1 (from mlagents==1.2.0.dev0)
#   Downloading torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting tensorboard>=2.14 (from mlagents==1.2.0.dev0)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting six>=1.16 (from mlagents==1.2.0.dev0)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting cattrs<1.7,>=1.1.0 (from mlagents==1.2.0.dev0)
#   Downloading cattrs-1.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents==1.2.0.dev0) (26.1.0)
# Collecting huggingface_hub>=0.14 (from mlagents==1.2.0.dev0)
#   Downloading huggingface_hub-1.16.1-py3-none-any.whl.metadata (14 kB)
# Collecting onnx==1.15.0 (from mlagents==1.2.0.dev0)
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: cloudpickle in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents_envs==1.2.0.dev0->mlagents==1.2.0.dev0) (3.1.2)
# Requirement already satisfied: gym>=0.21.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents_envs==1.2.0.dev0->mlagents==1.2.0.dev0) (0.26.2)
# Requirement already satisfied: pettingzoo==1.15.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents_envs==1.2.0.dev0->mlagents==1.2.0.dev0) (1.15.0)
# Requirement already satisfied: filelock>=3.4.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from mlagents_envs==1.2.0.dev0->mlagents==1.2.0.dev0) (3.29.0)
# Collecting typing-extensions>=4.10.0 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting sympy>=1.13.3 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.4.0 (from torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from triton==3.4.0->torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0) (82.0.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/envs/mlagents_env/lib/python3.10/site-packages (from gym>=0.21.0->mlagents_envs==1.2.0.dev0->mlagents==1.2.0.dev0) (0.1.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting tqdm>=4.42.1 (from huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting typer>=0.20.0 (from huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading idna-3.16-py3-none-any.whl.metadata (6.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch<=2.8.0,>=2.1.1->mlagents==1.2.0.dev0)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.14->mlagents==1.2.0.dev0)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.14->mlagents==1.2.0.dev0)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.14->mlagents==1.2.0.dev0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.14->mlagents==1.2.0.dev0)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting click>=8.2.1 (from typer>=0.20.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.20.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer>=0.20.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.20.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer>=0.20.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=13.8.0->typer>=0.20.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting markupsafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard>=2.14->mlagents==1.2.0.dev0)
#   Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.14->mlagents==1.2.0.dev0)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 83.6 MB/s  0:00:00
# Downloading cattrs-1.5.0-py3-none-any.whl (19 kB)
# Downloading torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl (888.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.0/888.0 MB 19.2 MB/s  0:00:19
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 16.0 MB/s  0:00:20
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 105.1 MB/s  0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 58.7 MB/s  0:00:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 46.0 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 25.8 MB/s  0:00:14
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 69.0 MB/s  0:00:02
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.2 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 63.0 MB/s  0:00:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 69.8 MB/s  0:00:03
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 68.6 MB/s  0:00:03
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 53.6 MB/s  0:00:05
# Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 63.4 MB/s  0:00:04
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 69.5 MB/s  0:00:00
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 MB 69.6 MB/s  0:00:02
# Downloading h5py-3.16.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 77.1 MB/s  0:00:00
# Downloading huggingface_hub-1.16.1-py3-none-any.whl (668 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 668.2/668.2 kB 32.1 MB/s  0:00:00
# Downloading hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 78.9 MB/s  0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 89.2 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 27.4 MB/s  0:00:00
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 148.7 MB/s  0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 138.0 MB/s  0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.1 MB/s  0:00:00
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading idna-3.16-py3-none-any.whl (74 kB)
# Downloading certifi-2026.5.20-py3-none-any.whl (134 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 94.1 MB/s  0:00:00
# Building wheels for collected packages: mlagents
#   Building editable for mlagents (pyproject.toml) ... done
#   Created wheel for mlagents: filename=mlagents-1.2.0.dev0-0.editable-py3-none-any.whl size=4112 sha256=49ba432ee8fc2621b645b6f5d438b8c0ca6adfb151aed401bb042c0ec0395b41
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nmvign8i/wheels/90/f9/f3/05444ae1e763d3ed872e12f2ca47ef57ad9f8045d927bf68ad
# Successfully built mlagents
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, triton, tqdm, tensorboard-data-server, sympy, six, shellingham, pygments, onnx, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, mdurl, markupsafe, markdown, idna, hf-xet, h5py, h11, fsspec, click, certifi, cattrs, annotated-doc, absl-py, werkzeug, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, markdown-it-py, jinja2, httpcore, exceptiongroup, tensorboard, rich, nvidia-cusolver-cu12, anyio, typer, torch, httpx, huggingface_hub, mlagents
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 [mlagents]
# Successfully installed absl-py-2.4.0 annotated-doc-0.0.4 anyio-4.13.0 cattrs-1.5.0 certifi-2026.5.20 click-8.4.1 exceptiongroup-1.3.1 fsspec-2026.4.0 h11-0.16.0 h5py-3.16.0 hf-xet-1.5.0 httpcore-1.0.9 httpx-0.28.1 huggingface_hub-1.16.1 idna-3.16 jinja2-3.1.6 markdown-3.10.2 markdown-it-py-4.2.0 markupsafe-3.0.3 mdurl-0.1.2 mlagents-1.2.0.dev0 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 onnx-1.15.0 pygments-2.20.0 rich-15.0.0 shellingham-1.5.4 six-1.17.0 sympy-1.14.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 torch-2.8.0 tqdm-4.67.3 triton-3.4.0 typer-0.25.1 typing-extensions-4.15.0 werkzeug-3.1.8

# %% [markdown]
# ## Download and move the environment zip file in `./trained-envs-executables/linux/`
#
# - Our environment executable is in a zip file.
# - We need to download it and place it to `./trained-envs-executables/linux/`

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %% [markdown]
# We downloaded the file Huggy.zip from https://github.com/huggingface/Huggy using `wget`

# %%
# !wget "https://github.com/huggingface/Huggy/raw/main/Huggy.zip" -O ./trained-envs-executables/linux/Huggy.zip
# Out:
# --2026-05-23 05:57:02--  https://github.com/huggingface/Huggy/raw/main/Huggy.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip [following]
# --2026-05-23 05:57:02--  https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/zip]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M  66.0MB/s    in 0.6s
#
# 2026-05-23 05:57:03 (66.0 MB/s) - ‘./trained-envs-executables/linux/Huggy.zip’ saved [39214997/39214997]

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %% [markdown]
# Make sure your file is accessible

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %% [markdown]
# ## Let's recap how this environment works
#
# ### The State Space: what Huggy "perceives."
#
# Huggy doesn't "see" his environment. Instead, we provide him information about the environment:
#
# - The target (stick) position
# - The relative position between himself and the target
# - The orientation of his legs.
#
# Given all this information, Huggy **can decide which action to take next to fulfill his goal**.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.jpg" alt="Huggy" width="100%">
#
#
# ### The Action Space: what moves Huggy can do
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy-action.jpg" alt="Huggy action" width="100%">
#
# **Joint motors drive huggy legs**. It means that to get the target, Huggy needs to **learn to rotate the joint motors of each of his legs correctly so he can move**.
#
# ### The Reward Function
#
# The reward function is designed so that **Huggy will fulfill his goal** : fetch the stick.
#
# Remember that one of the foundations of Reinforcement Learning is the *reward hypothesis*: a goal can be described as the **maximization of the expected cumulative reward**.
#
# Here, our goal is that Huggy **goes towards the stick but without spinning too much**. Hence, our reward function must translate this goal.
#
# Our reward function:
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/reward.jpg" alt="Huggy reward function" width="100%">
#
# - *Orientation bonus*: we **reward him for getting close to the target**.
# - *Time penalty*: a fixed-time penalty given at every action to **force him to get to the stick as fast as possible**.
# - *Rotation penalty*: we penalize Huggy if **he spins too much and turns too quickly**.
# - *Getting to the target reward*: we reward Huggy for **reaching the target**.

# %% [markdown]
# ## Create the Huggy config file
#
# - In ML-Agents, you define the **training hyperparameters into config.yaml files.**
#
# - For the scope of this notebook, we're not going to modify the hyperparameters, but if you want to try as an experiment, you should also try to modify some other hyperparameters, Unity provides very [good documentation explaining each of them here](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-Configuration-File.md).
#
# - But we need to create a config file for Huggy.
#
#   - To do that click on Folder logo on the left of your screen.
#
#   <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/create_file.png" alt="Create file" width="10%">
#
#   - Go to `/content/ml-agents/config/ppo`
#   - Right mouse click and create a new file called `Huggy.yaml`
#
#   <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/create-huggy.png" alt="Create huggy.yaml" width="20%">
#
# - Copy and paste the content below 🔽

# %% [markdown]
# ```yaml
# behaviors:
#   Huggy:
#     trainer_type: ppo
#     hyperparameters:
#       batch_size: 2048
#       buffer_size: 20480
#       learning_rate: 0.0003
#       beta: 0.005
#       epsilon: 0.2
#       lambd: 0.95
#       num_epoch: 3
#       learning_rate_schedule: linear
#     network_settings:
#       normalize: true
#       hidden_units: 512
#       num_layers: 3
#       vis_encode_type: simple
#     reward_signals:
#       extrinsic:
#         gamma: 0.995
#         strength: 1.0
#     checkpoint_interval: 200000
#     keep_checkpoints: 15
#     max_steps: 2e6
#     time_horizon: 1000
#     summary_freq: 50000
# ```

# %% [markdown]
# - Don't forget to save the file!

# %% [markdown]
# - **In the case you want to modify the hyperparameters**, in Google Colab notebook, you can click here to open the config.yaml: `/content/ml-agents/config/ppo/Huggy.yaml`
#
# - For instance **if you want to save more models during the training** (for now, we save every 200,000 training timesteps). You need to modify:
#   - `checkpoint_interval`: The number of training timesteps collected between each checkpoint.
#   - `keep_checkpoints`: The maximum number of model checkpoints to keep.
#
# => Just keep in mind that **decreasing the `checkpoint_interval` means more models to upload to the Hub and so a longer uploading time**
# We’re now ready to train our agent 🔥.

# %% [markdown]
# ## Train our agent
#
# To train our agent, we just need to **launch mlagents-learn and select the executable containing the environment.**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/mllearn.png" alt="ml learn function" width="100%">
#
# With ML Agents, we run a training script. We define four parameters:
#
# 1. `mlagents-learn <config>`: the path where the hyperparameter config file is.
# 2. `--env`: where the environment executable is.
# 3. `--run-id`: the name you want to give to your training run id.
# 4. `--no-graphics`: to not launch the visualization during the training.
#
# Train the model and use the `--resume` flag to continue training in case of interruption.
#
# > It will fail first time when you use `--resume`, try running the block again to bypass the error.

# %% [markdown]
# The training will take 30 to 45min depending on your machine (don't forget to **set up a GPU**), go take a ☕️you deserve it 🤗.

# %%
# Explicitly use mlagents-learn from the new conda environment using python -m
# !/usr/local/envs/mlagents_env/bin/python -m mlagents.trainers.learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy2" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.2.0.dev0,
#   ml-agents-envs: 1.2.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Huggy?team=0
# [INFO] Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	200000
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	even_checkpoints:	False
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Huggy. Step: 50000. Time Elapsed: 69.749 s. Mean Reward: 1.883. Std of Reward: 0.921. Training.
# [INFO] Huggy. Step: 100000. Time Elapsed: 131.150 s. Mean Reward: 2.459. Std of Reward: 1.069. Training.
# [INFO] Huggy. Step: 150000. Time Elapsed: 194.773 s. Mean Reward: 3.111. Std of Reward: 1.255. Training.
# [INFO] Huggy. Step: 200000. Time Elapsed: 254.731 s. Mean Reward: 3.317. Std of Reward: 1.436. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-199698.onnx
# [INFO] Huggy. Step: 250000. Time Elapsed: 319.491 s. Mean Reward: 3.562. Std of Reward: 1.568. Training.
# [INFO] Huggy. Step: 300000. Time Elapsed: 381.799 s. Mean Reward: 3.653. Std of Reward: 1.693. Training.
# [INFO] Huggy. Step: 350000. Time Elapsed: 445.645 s. Mean Reward: 3.723. Std of Reward: 1.681. Training.
# [INFO] Huggy. Step: 400000. Time Elapsed: 511.947 s. Mean Reward: 3.785. Std of Reward: 1.829. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-399898.onnx
# [INFO] Huggy. Step: 450000. Time Elapsed: 576.418 s. Mean Reward: 3.724. Std of Reward: 1.672. Training.
# [INFO] Huggy. Step: 500000. Time Elapsed: 643.637 s. Mean Reward: 3.701. Std of Reward: 1.756. Training.
# [INFO] Huggy. Step: 550000. Time Elapsed: 709.427 s. Mean Reward: 3.730. Std of Reward: 1.654. Training.
# [INFO] Huggy. Step: 600000. Time Elapsed: 777.850 s. Mean Reward: 3.837. Std of Reward: 1.777. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-599954.onnx
# [INFO] Huggy. Step: 650000. Time Elapsed: 843.159 s. Mean Reward: 3.717. Std of Reward: 1.833. Training.
# [INFO] Huggy. Step: 700000. Time Elapsed: 912.051 s. Mean Reward: 3.752. Std of Reward: 1.883. Training.
# [INFO] Huggy. Step: 750000. Time Elapsed: 975.801 s. Mean Reward: 3.775. Std of Reward: 1.917. Training.
# [INFO] Huggy. Step: 800000. Time Elapsed: 1041.512 s. Mean Reward: 3.856. Std of Reward: 1.875. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-799982.onnx
# [INFO] Huggy. Step: 850000. Time Elapsed: 1110.360 s. Mean Reward: 3.866. Std of Reward: 1.853. Training.
# [INFO] Huggy. Step: 900000. Time Elapsed: 1176.532 s. Mean Reward: 3.889. Std of Reward: 1.813. Training.
# [INFO] Huggy. Step: 950000. Time Elapsed: 1243.989 s. Mean Reward: 3.708. Std of Reward: 1.858. Training.
# [INFO] Huggy. Step: 1000000. Time Elapsed: 1308.403 s. Mean Reward: 3.964. Std of Reward: 1.907. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-999985.onnx
# [INFO] Huggy. Step: 1050000. Time Elapsed: 1381.649 s. Mean Reward: 3.971. Std of Reward: 1.785. Training.
# [INFO] Huggy. Step: 1100000. Time Elapsed: 1449.309 s. Mean Reward: 3.812. Std of Reward: 1.802. Training.
# [INFO] Huggy. Step: 1150000. Time Elapsed: 1516.487 s. Mean Reward: 3.818. Std of Reward: 1.847. Training.
# [INFO] Huggy. Step: 1200000. Time Elapsed: 1588.959 s. Mean Reward: 4.035. Std of Reward: 1.815. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1199990.onnx
# [INFO] Huggy. Step: 1250000. Time Elapsed: 1657.278 s. Mean Reward: 3.802. Std of Reward: 1.855. Training.
# [INFO] Huggy. Step: 1300000. Time Elapsed: 1728.870 s. Mean Reward: 3.898. Std of Reward: 1.859. Training.
# [INFO] Huggy. Step: 1350000. Time Elapsed: 1796.855 s. Mean Reward: 3.871. Std of Reward: 1.853. Training.
# [INFO] Huggy. Step: 1400000. Time Elapsed: 1871.528 s. Mean Reward: 3.921. Std of Reward: 1.739. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1399956.onnx
# [INFO] Huggy. Step: 1450000. Time Elapsed: 1940.119 s. Mean Reward: 3.781. Std of Reward: 1.913. Training.
# [INFO] Huggy. Step: 1500000. Time Elapsed: 2008.837 s. Mean Reward: 3.854. Std of Reward: 1.943. Training.
# [INFO] Huggy. Step: 1550000. Time Elapsed: 2083.223 s. Mean Reward: 3.818. Std of Reward: 1.876. Training.
# [INFO] Huggy. Step: 1600000. Time Elapsed: 2153.464 s. Mean Reward: 3.778. Std of Reward: 1.861. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1599958.onnx
# [INFO] Huggy. Step: 1650000. Time Elapsed: 2227.554 s. Mean Reward: 3.697. Std of Reward: 1.935. Training.
# [INFO] Huggy. Step: 1700000. Time Elapsed: 2297.071 s. Mean Reward: 3.822. Std of Reward: 1.883. Training.
# [INFO] Huggy. Step: 1750000. Time Elapsed: 2372.971 s. Mean Reward: 4.020. Std of Reward: 1.911. Training.
# [INFO] Huggy. Step: 1800000. Time Elapsed: 2441.565 s. Mean Reward: 3.820. Std of Reward: 1.885. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1799982.onnx
# [INFO] Huggy. Step: 1850000. Time Elapsed: 2509.832 s. Mean Reward: 3.714. Std of Reward: 1.966. Training.
# [INFO] Huggy. Step: 1900000. Time Elapsed: 2583.654 s. Mean Reward: 3.780. Std of Reward: 1.965. Training.
# [INFO] Huggy. Step: 1950000. Time Elapsed: 2652.840 s. Mean Reward: 3.769. Std of Reward: 1.988. Training.
# [INFO] Huggy. Step: 2000000. Time Elapsed: 2723.386 s. Mean Reward: 3.712. Std of Reward: 1.958. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1999996.onnx
# [INFO] Exported results/Huggy2/Huggy/Huggy-2000089.onnx
# [INFO] Copied results/Huggy2/Huggy/Huggy-2000089.onnx to results/Huggy2/Huggy.onnx.

# %% [markdown]
# ## Push the agent to the 🤗 Hub
#
# - Now that we trained our agent, we’re **ready to push it to the Hub to be able to play with Huggy on your browser🔥.**

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# Then, we simply need to run `mlagents-push-to-hf`.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/mlpush.png" alt="ml learn function" width="100%">

# %% [markdown]
# And we define 4 parameters:
#
# 1. `--run-id`: the name of the training run id.
# 2. `--local-dir`: where the agent was saved, it’s results/<run_id name>, so in my case results/First Training.
# 3. `--repo-id`: the name of the Hugging Face repo you want to create or update. It’s always <your huggingface username>/<the repo name>
# If the repo does not exist **it will be created automatically**
# 4. `--commit-message`: since HF repos are git repository you need to define a commit message.

# %%
# !/usr/local/envs/mlagents_env/bin/mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy2" --repo-id="MafeLeon9/ppo-Huggy" --commit-message="Huggy"
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   .../Huggy/Huggy-2000089.onnx:  22% 509k/2.27M [00:00<?, ?B/s]
#
#
#   ...uggy2/Huggy/checkpoint.pt:  19% 2.63M/13.5M [00:00<?, ?B/s]
#
#
#
#   ...2/Huggy/Huggy-799982.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#   .../Huggy/Huggy-1799982.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0:   4% 16.0k/389k [00:00<?, ?B/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-2000089.pt:  22% 3.02M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx:  22% 509k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199698.pt:   1% 75.4k/13.5M [00:00<?, ?B/s]
#
#   .../Huggy/Huggy-2000089.onnx:  22% 509k/2.27M [00:00<?, ?B/s]
#
#
#   ...uggy2/Huggy/checkpoint.pt:  19% 2.63M/13.5M [00:00<?, ?B/s]
#
#
#
#   ...2/Huggy/Huggy-799982.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#   .../Huggy/Huggy-1799982.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0:   4% 16.0k/389k [00:00<?, ?B/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx:   4% 93.4k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-2000089.pt:  22% 3.02M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx:  22% 509k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  11% 20.5M/190M [00:01<00:11, 14.5MB/s, 1.98MB/s  ]
# New Data Upload               :  10% 16.9M/171M [00:01<00:12, 12.0MB/s, 1.63MB/s  ]
#
#   .../Huggy/Huggy-2000089.onnx:  67% 1.53M/2.27M [00:00<00:00, 4.07MB/s]
#
#
#   ...uggy2/Huggy/checkpoint.pt:  58% 7.83M/13.5M [00:00<00:00, 20.8MB/s]
#
#
#
#   ...2/Huggy/Huggy-799982.onnx:  10% 234k/2.27M [00:00<00:03, 560kB/s]
#
#
#
#
#   .../Huggy/Huggy-1799982.onnx:  10% 234k/2.27M [00:00<00:03, 561kB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx:  10% 234k/2.27M [00:00<00:03, 561kB/s]
#
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0:  10% 39.9k/389k [00:00<00:03, 95.9kB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx:  10% 234k/2.27M [00:00<00:03, 561kB/s]
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-2000089.pt:  67% 9.07M/13.5M [00:00<00:00, 24.2MB/s]
#
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx:  67% 1.53M/2.27M [00:00<00:00, 4.08MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  32% 60.2M/190M [00:01<00:02, 43.8MB/s, 5.74MB/s  ]
# New Data Upload               :  29% 49.6M/171M [00:01<00:03, 36.0MB/s, 4.72MB/s  ]
#
#   .../Huggy/Huggy-2000089.onnx: 100% 2.27M/2.27M [00:00<00:00, 3.52MB/s]
#
#
#   ...uggy2/Huggy/checkpoint.pt:  87% 11.8M/13.5M [00:00<00:00, 18.4MB/s]
#
#
#
#   ...2/Huggy/Huggy-799982.onnx:  23% 514k/2.27M [00:00<00:02, 841kB/s]
#
#
#
#
#   .../Huggy/Huggy-1799982.onnx:  23% 514k/2.27M [00:00<00:02, 841kB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx:  23% 514k/2.27M [00:00<00:02, 841kB/s]
#
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0:  23% 87.9k/389k [00:00<00:02, 144kB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx:  23% 514k/2.27M [00:00<00:02, 842kB/s]
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-2000089.pt: 100% 13.5M/13.5M [00:00<00:00, 21.0MB/s]
#
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 3.53MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  49% 93.9M/190M [00:01<00:01, 64.1MB/s, 8.80MB/s  ]
# New Data Upload               :  46% 77.8M/171M [00:01<00:01, 53.2MB/s, 7.29MB/s  ]
#
#   .../Huggy/Huggy-2000089.onnx: 100% 2.27M/2.27M [00:00<00:00, 2.35MB/s]
#
#
#   ...uggy2/Huggy/checkpoint.pt:  91% 12.3M/13.5M [00:00<00:00, 12.9MB/s]
#
#
#
#   ...2/Huggy/Huggy-799982.onnx:  46% 1.05M/2.27M [00:00<00:00, 1.28MB/s]
#
#
#
#
#   .../Huggy/Huggy-1799982.onnx:  46% 1.05M/2.27M [00:00<00:00, 1.28MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx:  46% 1.05M/2.27M [00:00<00:00, 1.28MB/s]
#
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0:  46% 180k/389k [00:00<00:00, 219kB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx:  46% 1.05M/2.27M [00:00<00:00, 1.28MB/s]
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-2000089.pt: 100% 13.5M/13.5M [00:00<00:00, 14.0MB/s]
#
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 2.35MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  57% 108M/190M [00:02<00:01, 62.1MB/s, 9.91MB/s  ]
# New Data Upload               :  53% 90.8M/171M [00:02<00:01, 53.0MB/s, 8.35MB/s  ]
#
#   .../Huggy/Huggy-2000089.onnx: 100% 2.27M/2.27M [00:00<00:00, 1.76MB/s]
#
#
#   ...uggy2/Huggy/checkpoint.pt:  98% 13.2M/13.5M [00:00<00:00, 10.6MB/s]
#
#
#
#   ...2/Huggy/Huggy-799982.onnx:  86% 1.96M/2.27M [00:00<00:00, 1.87MB/s]
#
#
#
#
#   .../Huggy/Huggy-1799982.onnx:  86% 1.96M/2.27M [00:00<00:00, 1.87MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx:  86% 1.96M/2.27M [00:00<00:00, 1.87MB/s]
#
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0:  86% 335k/389k [00:00<00:00, 320kB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx:  86% 1.96M/2.27M [00:00<00:00, 1.87MB/s]
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-2000089.pt: 100% 13.5M/13.5M [00:00<00:00, 10.5MB/s]
#
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 1.76MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  69% 131M/190M [00:02<00:00, 70.4MB/s, 11.9MB/s  ]
# New Data Upload               :  66% 113M/171M [00:02<00:00, 62.1MB/s, 10.2MB/s  ]
#
#   .../Huggy/Huggy-2000089.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.41MB/s]
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:01<00:00, 8.70MB/s]
#
#
#
#   ...2/Huggy/Huggy-799982.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.74MB/s]
#
#
#
#
#   .../Huggy/Huggy-1799982.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.74MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.74MB/s]
#
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0: 100% 387k/389k [00:01<00:00, 297kB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.74MB/s]
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-2000089.pt: 100% 13.5M/13.5M [00:01<00:00, 8.39MB/s]
#
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.41MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (9 / 25)     :  75% 143M/190M [00:02<00:00, 64.2MB/s, 12.7MB/s  ]
# New Data Upload               :  73% 124M/171M [00:02<00:00, 57.6MB/s, 11.1MB/s  ]
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:01<00:00, 8.66MB/s]
#
#
#   ...2/Huggy/Huggy-799982.onnx: 100% 2.27M/2.27M [00:01<-00:00, -240kB/s]
#
#
#
#   .../Huggy/Huggy-1799982.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.45MB/s]
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.45MB/s]
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0: 100% 387k/389k [00:01<00:00, 196kB/s]
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.50MB/s]
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199698.pt:  69% 9.33M/13.5M [00:01<00:00, 6.16MB/s]
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999996.onnx: 100% 2.27M/2.27M [00:01<-00:00, -501kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999985.pt: 100% 13.5M/13.5M [00:01<00:00, 8.64MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (9 / 25)     :  90% 172M/190M [00:02<00:00, 77.8MB/s, 15.1MB/s  ]
# New Data Upload               :  89% 153M/171M [00:02<00:00, 73.1MB/s, 13.4MB/s  ]
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:01<00:00, 7.43MB/s]
#
#
#   ...2/Huggy/Huggy-799982.onnx: 100% 2.27M/2.27M [00:01<00:00, -201kB/s]
#
#
#
#   .../Huggy/Huggy-1799982.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.25MB/s]
#
#
#
#
#   .../Huggy/Huggy-1399956.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.25MB/s]
#
#
#
#
#
#   ...16980.b7ab1a4920ac.7744.0: 100% 389k/389k [00:01<00:00, 169kB/s]
#
#
#
#
#
#
#   ...2/Huggy/Huggy-999985.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.29MB/s]
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199698.pt:  99% 13.4M/13.5M [00:01<00:00, 7.62MB/s]
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999996.onnx: 100% 2.27M/2.27M [00:01<00:00, -429kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999985.pt: 100% 13.5M/13.5M [00:01<00:00, 7.43MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    : 100% 189M/190M [00:03<00:00, 76.0MB/s, 16.4MB/s  ]
# New Data Upload               : 100% 170M/171M [00:03<00:00, 72.6MB/s, 14.8MB/s  ]
#
#   ...gy2/Huggy/Huggy-199698.pt: 100% 13.5M/13.5M [00:02<00:00, 5.20MB/s]
#
#
#   .../Huggy/Huggy-1999996.onnx: 100% 2.27M/2.27M [00:02<00:00, -141kB/s]
#
#
#
#   ...gy2/Huggy/Huggy-999985.pt: 100% 13.5M/13.5M [00:02<00:00, 5.37MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1799982.pt: 100% 13.5M/13.5M [00:02<00:00, 5.37MB/s]
#
#
#
#
#
#   ...gy2/Huggy/Huggy-599954.pt: 100% 13.5M/13.5M [00:02<00:00, 5.37MB/s]
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199698.onnx: 100% 2.27M/2.27M [00:02<00:00, 903kB/s]
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1599958.onnx: 100% 2.27M/2.27M [00:02<00:00, 872kB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-799982.pt: 100% 13.5M/13.5M [00:02<00:00, 4.19MB/s]
#
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-1599958.pt: 100% 13.5M/13.5M [00:02<00:00, 5.20MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (25 / 25)    : 100% 190M/190M [00:03<00:00, 34.6MB/s, 15.3MB/s  ]
# Processing Files (25 / 25)    : 100% 190M/190M [00:04<00:00, 47.4MB/s, 15.3MB/s  ]
# New Data Upload               : 100% 171M/171M [00:04<00:00, 42.7MB/s, 13.8MB/s  ]
#   ...gy2/Huggy/Huggy-199698.pt: 100% 13.5M/13.5M [00:02<00:00, 5.01MB/s]
#   .../Huggy/Huggy-1999996.onnx: 100% 2.27M/2.27M [00:02<00:00, -135kB/s]
#   ...gy2/Huggy/Huggy-999985.pt: 100% 13.5M/13.5M [00:02<00:00, 5.17MB/s]
#   ...y2/Huggy/Huggy-1799982.pt: 100% 13.5M/13.5M [00:02<00:00, 5.17MB/s]
#   ...gy2/Huggy/Huggy-599954.pt: 100% 13.5M/13.5M [00:02<00:00, 5.17MB/s]
#   ...2/Huggy/Huggy-199698.onnx: 100% 2.27M/2.27M [00:02<00:00, 870kB/s]
#   .../Huggy/Huggy-1599958.onnx: 100% 2.27M/2.27M [00:02<00:00, 840kB/s]
#   ...gy2/Huggy/Huggy-799982.pt: 100% 13.5M/13.5M [00:02<00:00, 4.04MB/s]
#   ...y2/Huggy/Huggy-1599958.pt: 100% 13.5M/13.5M [00:02<00:00, 5.01MB/s]
#   ...y2/Huggy/Huggy-1399956.pt: 100% 13.5M/13.5M [00:02<00:00, 5.18MB/s]
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/MafeLeon9/ppo-Huggy

# %% [markdown]
# Else, if everything worked you should have this at the end of the process(but with a different url 😆) :
#
#
#
# ```
# Your model is pushed to the hub. You can view your model here: https://huggingface.co/ThomasSimonini/ppo-Huggy
# ```
#
# It’s the link to your model repository. The repository contains a model card that explains how to use the model, your Tensorboard logs and your config file. **What’s awesome is that it’s a git repository, which means you can have different commits, update your repository with a new push, open Pull Requests, etc.**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/modelcard.png" alt="ml learn function" width="100%">

# %% [markdown]
# But now comes the best: **being able to play with Huggy online 👀.**

# %% [markdown]
# ## Play with your Huggy 🐕
#
# This step is the simplest:
#
# - Open the game Huggy in your browser: https://huggingface.co/spaces/ThomasSimonini/Huggy
#
# - Click on Play with my Huggy model
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/load-huggy.jpg" alt="load-huggy" width="100%">

# %% [markdown]
# 1. In step 1, type your username (your username is case sensitive: for instance, my username is ThomasSimonini not thomassimonini or ThOmasImoNInI) and click on the search button.
#
# 2. In step 2, select your model repository.
#
# 3. In step 3, **choose which model you want to replay**:
#   - I have multiple ones, since we saved a model every 500000 timesteps.
#   - But since I want the more recent, I choose `Huggy.onnx`
#
# 👉 What’s nice **is to try with different models steps to see the improvement of the agent.**

# %% [markdown]
# Congrats on finishing this bonus unit!
#
# You can now sit and enjoy playing with your Huggy 🐶. And don't **forget to spread the love by sharing Huggy with your friends 🤗**. And if you share about it on social media, **please tag us @huggingface and me @simoninithomas**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy-cover.jpeg" alt="Huggy cover" width="100%">
#
#
# ## Keep Learning, Stay  awesome 🤗
