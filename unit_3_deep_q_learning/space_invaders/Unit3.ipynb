# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-7unhjvca
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-7unhjvca
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 22e3ff2450fd92033f7f032915e1f64894a09584
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.9.0a2 (from rl_zoo3==2.9.0a2)
#   Downloading sb3_contrib-2.9.0a2-py3-none-any.whl.metadata (4.1 kB)
# Collecting gymnasium<1.3.0,>=0.29.1 (from rl_zoo3==2.9.0a2)
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.9.0a2)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.9.0a2) (4.67.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.9.0a2) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.9.0a2)
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.9.0a2) (6.0.3)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.9.0a2)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.9.0a2)
#   Downloading shimmy-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.9.0a2) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.9.0a2) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.9.0a2) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.9.0a2) (0.0.4)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.9.0a2) (1.18.4)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.9.0a2)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.9.0a2) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.9.0a2) (2.0.49)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.12/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.9.0a2) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.9.0a2)
#   Downloading dataproperty-1.1.1-py3-none-any.whl.metadata (12 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.9.0a2)
#   Downloading mbstrdecoder-1.1.5-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.9.0a2)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.9.0a2)
#   Downloading tabledata-1.3.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.9.0a2)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.0a2)
#   Downloading typepy-1.3.5-py3-none-any.whl.metadata (9.6 kB)
# Collecting stable_baselines3<3.0,>=2.9.0a2 (from sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2)
#   Downloading stable_baselines3-2.9.0a2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.9.0a2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.9.0a2) (2.20.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.9.0a2) (1.3.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (1.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (2.32.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.9.0a2) (0.1.2)
# Requirement already satisfied: chardet<7,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.9.0a2) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.9.0a2) (3.4.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (2.10.0+cu128)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.0a2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.0a2) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.0a2) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (1.5.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.9.0a2) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.0a2) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.9.0a2->sb3_contrib<3.0,>=2.9.0a2->rl_zoo3==2.9.0a2) (1.3.0)
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 29.9 MB/s eta 0:00:00
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 25.6 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.5 MB/s eta 0:00:00
# Downloading sb3_contrib-2.9.0a2-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.7 MB/s eta 0:00:00
# Downloading shimmy-2.0.1-py3-none-any.whl (30 kB)
# Downloading dataproperty-1.1.1-py3-none-any.whl (27 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 40.4 MB/s eta 0:00:00
# Downloading mbstrdecoder-1.1.5-py3-none-any.whl (8.0 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.9.0a2-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 16.3 MB/s eta 0:00:00
# Downloading tabledata-1.3.5-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.5-py3-none-any.whl (31 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.9.0a2-py3-none-any.whl size=79013 sha256=a13ece84a9df1ea438cde850761ba07589f42810ccdb4726e9b5bdf3ed79ac45
#   Stored in directory: /tmp/pip-ephem-wheel-cache-monl7rzj/wheels/cd/09/5b/8130538724a187021e02afe53ce7a1269c516a78a487a1ba15
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, mbstrdecoder, gymnasium, colorlog, typepy, shimmy, huggingface-hub, optuna, huggingface_sb3, stable_baselines3, DataProperty, tabledata, sb3_contrib, pytablewriter, rl_zoo3
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.3.0
#     Uninstalling gymnasium-1.3.0:
#       Successfully uninstalled gymnasium-1.3.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.0.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.36.2 which is incompatible.
# Successfully installed DataProperty-1.1.1 colorlog-6.10.1 gymnasium-1.2.3 huggingface-hub-0.36.2 huggingface_sb3-3.0 mbstrdecoder-1.1.5 optuna-4.8.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.9.0a2 sb3_contrib-2.9.0a2 shimmy-2.0.1 stable_baselines3-2.9.0a2 tabledata-1.3.5 tcolorpy-0.1.7 typepy-1.3.5

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 51 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 0s (10.5 MB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 122363 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# %%writefile dqn.yml
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   optimize_memory_usage: False
# Out:
# Writing dqn.yml

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 248      |
# |    time_elapsed     | 2221     |
# |    total_timesteps  | 552014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 113003   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 248      |
# |    time_elapsed     | 2223     |
# |    total_timesteps  | 552682   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 113170   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 248      |
# |    time_elapsed     | 2227     |
# |    total_timesteps  | 553645   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 113411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 248      |
# |    time_elapsed     | 2231     |
# |    total_timesteps  | 554557   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 113639   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 248      |
# |    time_elapsed     | 2235     |
# |    total_timesteps  | 555532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 113882   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 248      |
# |    time_elapsed     | 2240     |
# |    total_timesteps  | 556867   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 114216   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 248      |
# |    time_elapsed     | 2244     |
# |    total_timesteps  | 557738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0255   |
# |    n_updates        | 114434   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 248      |
# |    time_elapsed     | 2247     |
# |    total_timesteps  | 558614   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 114653   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 248      |
# |    time_elapsed     | 2252     |
# |    total_timesteps  | 559720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0291   |
# |    n_updates        | 114929   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 248      |
# |    time_elapsed     | 2256     |
# |    total_timesteps  | 560841   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 115210   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 248      |
# |    time_elapsed     | 2261     |
# |    total_timesteps  | 562039   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 115509   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 248      |
# |    time_elapsed     | 2265     |
# |    total_timesteps  | 563038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 115759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 248      |
# |    time_elapsed     | 2272     |
# |    total_timesteps  | 564581   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0426   |
# |    n_updates        | 116145   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 248      |
# |    time_elapsed     | 2273     |
# |    total_timesteps  | 564902   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.051    |
# |    n_updates        | 116225   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 248      |
# |    time_elapsed     | 2277     |
# |    total_timesteps  | 565871   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0815   |
# |    n_updates        | 116467   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 248      |
# |    time_elapsed     | 2280     |
# |    total_timesteps  | 566767   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 116691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 248      |
# |    time_elapsed     | 2286     |
# |    total_timesteps  | 567990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 116997   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 248      |
# |    time_elapsed     | 2289     |
# |    total_timesteps  | 568845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0349   |
# |    n_updates        | 117211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 248      |
# |    time_elapsed     | 2294     |
# |    total_timesteps  | 570105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 117526   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 248      |
# |    time_elapsed     | 2298     |
# |    total_timesteps  | 570899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 117724   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 248      |
# |    time_elapsed     | 2303     |
# |    total_timesteps  | 572161   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 118040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 248      |
# |    time_elapsed     | 2308     |
# |    total_timesteps  | 573391   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 118347   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 248      |
# |    time_elapsed     | 2313     |
# |    total_timesteps  | 574591   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0824   |
# |    n_updates        | 118647   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=450.00 +/- 57.18
# Episode length: 3102.60 +/- 406.16
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.1e+03  |
# |    mean_reward      | 450      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0283   |
# |    n_updates        | 118749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 247      |
# |    time_elapsed     | 2324     |
# |    total_timesteps  | 575038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 118759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 247      |
# |    time_elapsed     | 2329     |
# |    total_timesteps  | 576063   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 119015   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 247      |
# |    time_elapsed     | 2334     |
# |    total_timesteps  | 577332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 119332   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 247      |
# |    time_elapsed     | 2339     |
# |    total_timesteps  | 578451   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 119612   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 247      |
# |    time_elapsed     | 2346     |
# |    total_timesteps  | 580046   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 120011   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 247      |
# |    time_elapsed     | 2350     |
# |    total_timesteps  | 581041   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0628   |
# |    n_updates        | 120260   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 247      |
# |    time_elapsed     | 2353     |
# |    total_timesteps  | 581872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 120467   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 247      |
# |    time_elapsed     | 2359     |
# |    total_timesteps  | 583246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0364   |
# |    n_updates        | 120811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 247      |
# |    time_elapsed     | 2362     |
# |    total_timesteps  | 583957   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 120989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 247      |
# |    time_elapsed     | 2369     |
# |    total_timesteps  | 585701   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 121425   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 247      |
# |    time_elapsed     | 2372     |
# |    total_timesteps  | 586423   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 121605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 247      |
# |    time_elapsed     | 2375     |
# |    total_timesteps  | 587096   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 121773   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 247      |
# |    time_elapsed     | 2379     |
# |    total_timesteps  | 588258   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 122064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 247      |
# |    time_elapsed     | 2385     |
# |    total_timesteps  | 589412   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 122352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 247      |
# |    time_elapsed     | 2391     |
# |    total_timesteps  | 590973   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0359   |
# |    n_updates        | 122743   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 247      |
# |    time_elapsed     | 2398     |
# |    total_timesteps  | 592714   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 123178   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 247      |
# |    time_elapsed     | 2403     |
# |    total_timesteps  | 593920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 123479   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 247      |
# |    time_elapsed     | 2406     |
# |    total_timesteps  | 594854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 123713   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 247      |
# |    time_elapsed     | 2411     |
# |    total_timesteps  | 595967   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 123991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 247      |
# |    time_elapsed     | 2418     |
# |    total_timesteps  | 597661   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 124415   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 428      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 247      |
# |    time_elapsed     | 2425     |
# |    total_timesteps  | 599230   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 124807   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=526.00 +/- 136.29
# Episode length: 4072.60 +/- 893.28
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.07e+03 |
# |    mean_reward      | 526      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 124999   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 245      |
# |    time_elapsed     | 2441     |
# |    total_timesteps  | 600412   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 125102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 428      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 245      |
# |    time_elapsed     | 2446     |
# |    total_timesteps  | 601556   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 125388   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 245      |
# |    time_elapsed     | 2453     |
# |    total_timesteps  | 603221   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 125805   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 245      |
# |    time_elapsed     | 2459     |
# |    total_timesteps  | 604731   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 126182   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 245      |
# |    time_elapsed     | 2463     |
# |    total_timesteps  | 605573   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 126393   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 245      |
# |    time_elapsed     | 2468     |
# |    total_timesteps  | 606960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 126739   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 245      |
# |    time_elapsed     | 2472     |
# |    total_timesteps  | 607751   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 126937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 245      |
# |    time_elapsed     | 2477     |
# |    total_timesteps  | 609120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0533   |
# |    n_updates        | 127279   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 245      |
# |    time_elapsed     | 2488     |
# |    total_timesteps  | 611603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 127900   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 437      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 245      |
# |    time_elapsed     | 2491     |
# |    total_timesteps  | 612563   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 128140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 245      |
# |    time_elapsed     | 2494     |
# |    total_timesteps  | 613243   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 128310   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 245      |
# |    time_elapsed     | 2499     |
# |    total_timesteps  | 614342   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 128585   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 245      |
# |    time_elapsed     | 2502     |
# |    total_timesteps  | 615186   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 128796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 245      |
# |    time_elapsed     | 2505     |
# |    total_timesteps  | 615800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 128949   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 245      |
# |    time_elapsed     | 2509     |
# |    total_timesteps  | 616848   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 129211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 245      |
# |    time_elapsed     | 2513     |
# |    total_timesteps  | 617740   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 129434   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 245      |
# |    time_elapsed     | 2517     |
# |    total_timesteps  | 618763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 129690   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 245      |
# |    time_elapsed     | 2521     |
# |    total_timesteps  | 619763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 129940   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 245      |
# |    time_elapsed     | 2527     |
# |    total_timesteps  | 621121   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 130280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 245      |
# |    time_elapsed     | 2532     |
# |    total_timesteps  | 622382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 130595   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 245      |
# |    time_elapsed     | 2537     |
# |    total_timesteps  | 623686   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 130921   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 245      |
# |    time_elapsed     | 2541     |
# |    total_timesteps  | 624475   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 131118   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=459.00 +/- 168.03
# Episode length: 3627.40 +/- 983.03
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.63e+03 |
# |    mean_reward      | 459      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 244      |
# |    time_elapsed     | 2556     |
# |    total_timesteps  | 625687   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0373   |
# |    n_updates        | 131421   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 244      |
# |    time_elapsed     | 2563     |
# |    total_timesteps  | 627369   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 131842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 244      |
# |    time_elapsed     | 2567     |
# |    total_timesteps  | 628491   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 132122   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 428      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 244      |
# |    time_elapsed     | 2572     |
# |    total_timesteps  | 629641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 132410   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 432      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 244      |
# |    time_elapsed     | 2576     |
# |    total_timesteps  | 630713   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 132678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 244      |
# |    time_elapsed     | 2585     |
# |    total_timesteps  | 632925   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 133231   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 244      |
# |    time_elapsed     | 2592     |
# |    total_timesteps  | 634558   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0415   |
# |    n_updates        | 133639   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 244      |
# |    time_elapsed     | 2599     |
# |    total_timesteps  | 636235   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 134058   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 244      |
# |    time_elapsed     | 2602     |
# |    total_timesteps  | 637089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 134272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 244      |
# |    time_elapsed     | 2606     |
# |    total_timesteps  | 638050   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 134512   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 244      |
# |    time_elapsed     | 2611     |
# |    total_timesteps  | 639352   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00946  |
# |    n_updates        | 134837   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 244      |
# |    time_elapsed     | 2615     |
# |    total_timesteps  | 640215   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 135053   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 244      |
# |    time_elapsed     | 2620     |
# |    total_timesteps  | 641451   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 135362   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 244      |
# |    time_elapsed     | 2628     |
# |    total_timesteps  | 643353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0581   |
# |    n_updates        | 135838   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 244      |
# |    time_elapsed     | 2636     |
# |    total_timesteps  | 645272   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 136317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 456      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 244      |
# |    time_elapsed     | 2639     |
# |    total_timesteps  | 646006   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 136501   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 454      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 244      |
# |    time_elapsed     | 2643     |
# |    total_timesteps  | 646864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00938  |
# |    n_updates        | 136715   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 244      |
# |    time_elapsed     | 2648     |
# |    total_timesteps  | 648122   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 137030   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 244      |
# |    time_elapsed     | 2655     |
# |    total_timesteps  | 649991   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 137497   |
# ----------------------------------
# Eval num_timesteps=650000, episode_reward=473.00 +/- 110.57
# Episode length: 3321.40 +/- 431.77
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.32e+03 |
# |    mean_reward      | 473      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 650000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0389   |
# |    n_updates        | 137499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 243      |
# |    time_elapsed     | 2669     |
# |    total_timesteps  | 651063   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.057    |
# |    n_updates        | 137765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 459      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 243      |
# |    time_elapsed     | 2674     |
# |    total_timesteps  | 652185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.055    |
# |    n_updates        | 138046   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# ...
# |    n_updates        | 213417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 237      |
# |    time_elapsed     | 4030     |
# |    total_timesteps  | 955676   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 213918   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 237      |
# |    time_elapsed     | 4036     |
# |    total_timesteps  | 957140   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 214284   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 237      |
# |    time_elapsed     | 4042     |
# |    total_timesteps  | 958700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 214674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 237      |
# |    time_elapsed     | 4049     |
# |    total_timesteps  | 960489   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 215122   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 237      |
# |    time_elapsed     | 4057     |
# |    total_timesteps  | 962440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 215609   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 237      |
# |    time_elapsed     | 4061     |
# |    total_timesteps  | 963664   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 215915   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 237      |
# |    time_elapsed     | 4067     |
# |    total_timesteps  | 964995   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 216248   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 237      |
# |    time_elapsed     | 4072     |
# |    total_timesteps  | 966245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 216561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 237      |
# |    time_elapsed     | 4080     |
# |    total_timesteps  | 968261   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 217065   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 237      |
# |    time_elapsed     | 4089     |
# |    total_timesteps  | 970521   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 217630   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 237      |
# |    time_elapsed     | 4096     |
# |    total_timesteps  | 972311   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 218077   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22e+03 |
# |    ep_rew_mean      | 611      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 237      |
# |    time_elapsed     | 4101     |
# |    total_timesteps  | 973757   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00875  |
# |    n_updates        | 218439   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=704.00 +/- 233.27
# Episode length: 4705.80 +/- 1007.55
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.71e+03 |
# |    mean_reward      | 704      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.172    |
# |    n_updates        | 218749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22e+03 |
# |    ep_rew_mean      | 613      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 236      |
# |    time_elapsed     | 4120     |
# |    total_timesteps  | 975117   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 218779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21e+03 |
# |    ep_rew_mean      | 609      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 236      |
# |    time_elapsed     | 4126     |
# |    total_timesteps  | 976505   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 219126   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 236      |
# |    time_elapsed     | 4130     |
# |    total_timesteps  | 977521   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 219380   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 236      |
# |    time_elapsed     | 4137     |
# |    total_timesteps  | 979300   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0416   |
# |    n_updates        | 219824   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 236      |
# |    time_elapsed     | 4141     |
# |    total_timesteps  | 980525   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 220131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 236      |
# |    time_elapsed     | 4147     |
# |    total_timesteps  | 981739   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 220434   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 236      |
# |    time_elapsed     | 4154     |
# |    total_timesteps  | 983582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 220895   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 236      |
# |    time_elapsed     | 4160     |
# |    total_timesteps  | 985143   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 221285   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 236      |
# |    time_elapsed     | 4168     |
# |    total_timesteps  | 987135   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 221783   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 236      |
# |    time_elapsed     | 4173     |
# |    total_timesteps  | 988324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 222080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 236      |
# |    time_elapsed     | 4178     |
# |    total_timesteps  | 989759   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 222439   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 236      |
# |    time_elapsed     | 4185     |
# |    total_timesteps  | 991276   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00784  |
# |    n_updates        | 222818   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 593      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 236      |
# |    time_elapsed     | 4187     |
# |    total_timesteps  | 991984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 222995   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 236      |
# |    time_elapsed     | 4192     |
# |    total_timesteps  | 993091   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 223272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 236      |
# |    time_elapsed     | 4202     |
# |    total_timesteps  | 995833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 223958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3940     |
# |    fps              | 236      |
# |    time_elapsed     | 4209     |
# |    total_timesteps  | 997334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 224333   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=715.00 +/- 241.52
# Episode length: 4808.00 +/- 1577.07
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.81e+03 |
# |    mean_reward      | 715      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 224999   |
# ----------------------------------
# New best mean reward!
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2026-05-23 10:23:17.017370: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 1105.00
# Atari Episode Length 7593
# Atari Episode Score: 570.00
# Atari Episode Length 3926
# Atari Episode Score: 600.00
# Atari Episode Length 4461
# Atari Episode Score: 545.00
# Atari Episode Length 3542

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga MafeLeon9 -f logs/
# Out:
# 2026-05-23 10:25:53.361668: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to MafeLeon9/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# .gitattributes: 1.52kB [00:00, 349kB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  2.74it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpbkb5rx81/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /tmp/tmpbkb5rx81/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpbkb5rx81/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpbkb5rx81/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
# Processing Files (1 / 1)      :   0% 1.26k/54.3M [00:00<7:42:17, 1.96kB/s, 4.93kB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   1% 200k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   1% 200k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   1% 404k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:   1% 548/37.0k [00:00<?, ?B/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   1% 200k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   1% 200k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   1% 404k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
# Processing Files (1 / 5)      :   1% 806k/54.3M [00:01<00:56, 946kB/s, 1.23MB/s  ]
# New Data Upload               :   1% 798k/53.8M [00:01<01:09, 764kB/s, 1.22MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   6% 801k/13.5M [00:00<00:04, 3.00MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   6% 801k/13.5M [00:00<00:04, 3.00MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   6% 1.61M/27.2M [00:00<00:04, 6.04MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :   6% 3.22M/54.3M [00:01<00:13, 3.74MB/s, 3.76MB/s  ]
# New Data Upload               :   6% 3.19M/53.8M [00:01<00:15, 3.17MB/s, 3.73MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  22% 3.00M/13.5M [00:00<00:01, 7.00MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  22% 3.00M/13.5M [00:00<00:01, 7.00MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  22% 6.05M/27.2M [00:00<00:01, 14.1MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  22% 12.1M/54.3M [00:01<00:02, 14.4MB/s, 11.4MB/s  ]
# New Data Upload               :  22% 12.0M/53.8M [00:01<00:03, 12.7MB/s, 11.3MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  49% 6.61M/13.5M [00:00<00:00, 10.7MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  49% 6.61M/13.5M [00:00<00:00, 10.7MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  49% 13.3M/27.2M [00:00<00:00, 21.5MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  49% 26.6M/54.3M [00:01<00:00, 30.3MB/s, 21.1MB/s  ]
# New Data Upload               :  49% 26.3M/53.8M [00:01<00:00, 27.6MB/s, 21.0MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  79% 10.6M/13.5M [00:00<00:00, 13.0MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  79% 10.6M/13.5M [00:00<00:00, 13.0MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  79% 21.4M/27.2M [00:00<00:00, 26.2MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  79% 42.7M/54.3M [00:01<00:00, 44.5MB/s, 29.3MB/s  ]
# New Data Upload               :  79% 42.3M/53.8M [00:01<00:00, 41.4MB/s, 29.1MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  99% 13.4M/13.5M [00:01<00:00, 13.2MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  99% 13.4M/13.5M [00:01<00:00, 13.2MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 27.0M/27.2M [00:01<00:00, 26.6MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  99% 53.9M/54.3M [00:02<00:00, 47.8MB/s, 32.6MB/s  ]
# New Data Upload               :  99% 53.5M/53.8M [00:02<00:00, 45.3MB/s, 32.3MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  99% 13.4M/13.5M [00:01<00:00, 11.0MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  99% 13.4M/13.5M [00:01<00:00, 11.0MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 27.0M/27.2M [00:01<00:00, 22.2MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:  99% 36.7k/37.0k [00:01<00:00, 30.1kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  99% 13.4M/13.5M [00:01<00:00, 9.44MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  99% 13.4M/13.5M [00:01<00:00, 9.44MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 27.0M/27.2M [00:01<00:00, 19.0MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:  99% 36.7k/37.0k [00:01<00:00, 25.8kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<00:00, 8.31MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 8.31MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 16.8MB/s]
#
#
#
#
#
# Processing Files (5 / 5)      : 100% 54.3M/54.3M [00:02<00:00, 21.8MB/s, 24.0MB/s  ]
# New Data Upload               : 100% 53.8M/53.8M [00:02<00:00, 21.2MB/s, 23.8MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<00:00, 7.39MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 7.39MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 14.9MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip: 100% 37.0k/37.0k [00:01<00:00, 20.2kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:02<00:00, 6.65MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:02<00:00, 6.65MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:02<00:00, 13.4MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip: 100% 37.0k/37.0k [00:02<00:00, 18.2kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:02<00:00, 6.54MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:02<00:00, 6.54MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:02<00:00, 13.2MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip: 100% 37.0k/37.0k [00:02<00:00, 17.9kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:02<00:00, 6.05MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:02<00:00, 6.05MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:02<00:00, 12.2MB/s]
#
#
#
#
#
# Processing Files (5 / 5)      : 100% 54.3M/54.3M [00:03<00:00, 16.7MB/s, 19.0MB/s  ]
# New Data Upload               : 100% 53.8M/53.8M [00:03<00:00, 16.6MB/s, 18.8MB/s  ]
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:02<00:00, 6.04MB/s]
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:02<00:00, 6.04MB/s]
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:02<00:00, 12.2MB/s]
#   ...v4/train_eval_metrics.zip: 100% 37.0k/37.0k [00:02<00:00, 16.5kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/MafeLeon9/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# 2026-05-23 10:27:54.019388: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# dqn-BeamRiderNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 33.2MB/s]
# config.yml: 100% 548/548 [00:00<00:00, 3.35MB/s]
# No normalization file
# args.yml: 100% 887/887 [00:00<00:00, 6.95MB/s]
# env_kwargs.yml: 100% 3.00/3.00 [00:00<00:00, 20.7kB/s]
# train_eval_metrics.zip: 100% 244k/244k [00:00<00:00, 586kB/s]
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_1

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# 2026-05-23 10:28:15.587383: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code expected at least 16 arguments, got 15
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/base_class.py:773: UserWarning: You are probably loading a DQN model saved with SB3 < 2.4.0, we truncated the optimizer state so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/pull/1963 for more info). Original error: loaded state dict contains a parameter group that doesn't match the size of optimizer's group
# Note: the model should still work fine, this only a warning.
#   warnings.warn(
# Atari Episode Score: 3028.00
# Atari Episode Length 14816

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
